# %%
import chromadb
from chromadb.utils import embedding_functions
client = chromadb.PersistentClient(path='./chroma_db')
col = client.get_collection('f1_knowledge', embedding_function=embedding_functions.DefaultEmbeddingFunction())
results = col.query(query_texts=['safety car probability rate'], n_results=3)
for doc in results['documents'][0]:
    print(doc[:200])
    print('---')
# Out:
# Safety car strategy advice for Austrian Grand Prix:
# Circuit type: High-speed | Average speed: 223.01 km/h
# Historical safety car appearance rate for High-speed circuits: 75%
# When a safety car is deploy
# ---
# Safety car strategy advice for Las Vegas Grand Prix:
# Circuit type: High-speed | Average speed: 226.03 km/h
# Historical safety car appearance rate for High-speed circuits: 75%
# When a safety car is deplo
# ---
# Safety car strategy advice for Dutch Grand Prix:
# Circuit type: Mixed | Average speed: 203.22 km/h
# Historical safety car appearance rate for Mixed circuits: 50%
# When a safety car is deployed in Formula
# ---
