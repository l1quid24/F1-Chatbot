# %%
import google.generativeai as genai
genai.configure(api_key='AIzaSyDvyQ3dIebAt19l26YJUJiKy8gcvDkY1e0')
for m in genai.list_models():
    if 'generateContent' in m.supported_generation_methods:
        print(m.name)
# Out:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# models/gemma-3-27b-it
# models/gemma-3n-e4b-it
# models/gemma-3n-e2b-it
# models/gemma-4-26b-a4b-it
# models/gemma-4-31b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image
# models/gemini-3-pro-preview
# models/gemini-3-flash-preview
# models/gemini-3.1-pro-preview
# models/gemini-3.1-pro-preview-customtools
# models/gemini-3.1-flash-lite-preview
# models/gemini-3-pro-image-preview
# models/nano-banana-pro-preview
# models/gemini-3.1-flash-image-preview
# models/lyria-3-clip-preview
# models/lyria-3-pro-preview
# models/gemini-robotics-er-1.5-preview
# models/gemini-2.5-computer-use-preview-10-2025
# models/deep-research-pro-preview-12-2025

# %%
# %pip install spacy
# Out:
# Collecting spacy
#   Downloading spacy-3.8.14-cp312-cp312-win_amd64.whl.metadata (28 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy)
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy)
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy)
#   Downloading murmurhash-1.0.15-cp312-cp312-win_amd64.whl.metadata (2.3 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy)
#   Downloading cymem-2.0.13-cp312-cp312-win_amd64.whl.metadata (9.9 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy)
#   Downloading preshed-3.0.13-cp312-cp312-win_amd64.whl.metadata (5.4 kB)
# Collecting thinc<8.4.0,>=8.3.12 (from spacy)
#   Downloading thinc-8.3.13-cp312-cp312-win_amd64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy)
#   Downloading wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.5.3 (from spacy)
#   Downloading srsly-2.5.3-cp312-cp312-win_amd64.whl.metadata (20 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy)
#   Downloading catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<2.0.0,>=1.0.0 (from spacy)
#   Downloading weasel-1.0.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting confection<2.0.0,>=1.3.2 (from spacy)
#   Downloading confection-1.3.3-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\Users\litia\anaconda3\envs\venv\Lib\site-packages (from spacy) (0.24.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\Users\litia\anaconda3\envs\venv\Lib\site-packages (from spacy) (4.67.3)
# Requirement already satisfied: numpy>=1.19.0 in c:\Users\litia\anaconda3\envs\venv\Lib\site-packages (from spacy) (2.3.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\Users\litia\anaconda3\envs\venv\Lib\site-packages (from spacy) (2.32.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in c:\Users\litia\anaconda3\envs\venv\Lib\site-packages (from spacy) (2.12.5)
# Requirement already satisfied: jinja2 in c:\Users\litia\anaconda3\envs\venv\Lib\site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in c:\Users\litia\anaconda3\envs\venv\Lib\site-packages (from spacy) (80.10.2)
# Requirement already satisfied: packaging>=20.0 in C:\Users\litia\AppData\Roaming\Python\Python312\site-packages (from spacy) (24.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\litia\anaconda3\envs\venv\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\Users\litia\anaconda3\envs\venv\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\Users\litia\anaconda3\envs\venv\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Users\litia\anaconda3\envs\venv\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\litia\anaconda3\envs\venv\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\Users\litia\anaconda3\envs\venv\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\Users\litia\anaconda3\envs\venv\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\Users\litia\anaconda3\envs\venv\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2026.1.4)
# Collecting blis<1.4.0,>=1.3.0 (from thinc<8.4.0,>=8.3.12->spacy)
#   Downloading blis-1.3.3-cp312-cp312-win_amd64.whl.metadata (7.7 kB)
# Requirement already satisfied: colorama in C:\Users\litia\AppData\Roaming\Python\Python312\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click>=8.2.1 in c:\Users\litia\anaconda3\envs\venv\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.3.2)
# Requirement already satisfied: shellingham>=1.3.0 in c:\Users\litia\anaconda3\envs\venv\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in c:\Users\litia\anaconda3\envs\venv\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (14.3.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\Users\litia\anaconda3\envs\venv\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (0.0.4)
# Collecting cloudpathlib>=0.7.0 (from weasel<2.0.0,>=1.0.0->spacy)
#   Downloading cloudpathlib-0.23.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: smart-open>=5.2.1 in c:\Users\litia\anaconda3\envs\venv\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (7.5.1)
# Requirement already satisfied: httpx>=0.24.0 in c:\Users\litia\anaconda3\envs\venv\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.28.1)
# Requirement already satisfied: anyio in c:\Users\litia\anaconda3\envs\venv\Lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (4.13.0)
# Requirement already satisfied: httpcore==1.* in c:\Users\litia\anaconda3\envs\venv\Lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\Users\litia\anaconda3\envs\venv\Lib\site-packages (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\Users\litia\anaconda3\envs\venv\Lib\site-packages (from rich>=12.3.0->typer<1.0.0,>=0.3.0->spacy) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\litia\AppData\Roaming\Python\Python312\site-packages (from rich>=12.3.0->typer<1.0.0,>=0.3.0->spacy) (2.17.2)
# Requirement already satisfied: mdurl~=0.1 in c:\Users\litia\anaconda3\envs\venv\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Requirement already satisfied: wrapt in c:\Users\litia\anaconda3\envs\venv\Lib\site-packages (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy) (2.1.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\Users\litia\anaconda3\envs\venv\Lib\site-packages (from jinja2->spacy) (3.0.3)
# Downloading spacy-3.8.14-cp312-cp312-win_amd64.whl (14.2 MB)
#    ---------------------------------------- 0.0/14.2 MB ? eta -:--:--
#    ----- ---------------------------------- 2.1/14.2 MB 13.1 MB/s eta 0:00:01
#    ------------------------ --------------- 8.7/14.2 MB 22.4 MB/s eta 0:00:01
#    ---------------------------------------- 14.2/14.2 MB 26.3 MB/s  0:00:00
# Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Downloading confection-1.3.3-py3-none-any.whl (35 kB)
# Downloading cymem-2.0.13-cp312-cp312-win_amd64.whl (40 kB)
# Downloading murmurhash-1.0.15-cp312-cp312-win_amd64.whl (25 kB)
# Downloading preshed-3.0.13-cp312-cp312-win_amd64.whl (122 kB)
# Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Downloading srsly-2.5.3-cp312-cp312-win_amd64.whl (652 kB)
#    ---------------------------------------- 0.0/652.5 kB ? eta -:--:--
#    ---------------------------------------- 652.5/652.5 kB ?  0:00:00
# Downloading thinc-8.3.13-cp312-cp312-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 1.7/1.7 MB 47.1 MB/s  0:00:00
# Downloading blis-1.3.3-cp312-cp312-win_amd64.whl (6.2 MB)
#    ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#    ---------------------------------------- 6.2/6.2 MB 42.1 MB/s  0:00:00
# Downloading wasabi-1.1.3-py3-none-any.whl (27 kB)
# Downloading weasel-1.0.0-py3-none-any.whl (50 kB)
# Downloading cloudpathlib-0.23.0-py3-none-any.whl (62 kB)
# Installing collected packages: wasabi, spacy-loggers, spacy-legacy, murmurhash, cymem, confection, cloudpathlib, catalogue, blis, srsly, preshed, thinc, weasel, spacy
#
#    ----- ----------------------------------  2/14 [spacy-legacy]
#    ----------------- ----------------------  6/14 [cloudpathlib]
#    ---------------------- -----------------  8/14 [blis]
#    ------------------------- --------------  9/14 [srsly]
#    ------------------------- --------------  9/14 [srsly]
#    ------------------------------- -------- 11/14 [thinc]
#    ------------------------------- -------- 11/14 [thinc]
#    ------------------------------- -------- 11/14 [thinc]
#    ------------------------------- -------- 11/14 [thinc]
#    ---------------------------------- ----- 12/14 [weasel]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ------------------------------------- -- 13/14 [spacy]
#    ---------------------------------------- 14/14 [spacy]
#
# Successfully installed blis-1.3.3 catalogue-2.0.10 cloudpathlib-0.23.0 confection-1.3.3 cymem-2.0.13 murmurhash-1.0.15 preshed-3.0.13 spacy-3.8.14 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.5.3 thinc-8.3.13 wasabi-1.1.3 weasel-1.0.0
# Note: you may need to restart the kernel to use updated packages.
